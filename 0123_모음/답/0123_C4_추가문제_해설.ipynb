# %%
답변 : 중심극한정리

해설 :
- 카페 한 명당 주문 시간은 균등하지 않고 들쑥날쑥하다.

- 개인별 주문 시간의 변동성이 크다.

- 극단값(이상치, outlier)이 존재한다.

 (예를 들어, 주문할 때 어떤 고객은 2분 소요, 어떤 고객은 10분 이상 소요)

- 오른쪽 꼬리가 긴 분포일 가능성 큼, 결국 종모양으로 변한다.

- 분포가 넓게 퍼져 있으며, 정규분포일 필요도 없다.(비대칭, 꼬리 김 가능)

📌 즉, 개별 관측값의 분산이 크고 분포 형태가 불규칙하다.

중심극한정리 (Central Limit Theorem) :
원래 데이터의 분포가 어떻든지 간에 표본 크기가 충분히 크면 표본평균의 분포는 정규분포에 가까워진다.
