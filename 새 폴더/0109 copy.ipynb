# %%
class Aiffel:
    def cheer(self):
        print('끝까지 화이팅!')

# %%
a = Aiffel()

# %%
a.cheer()
# Out:
# 끝까지 화이팅!

# %%
class Aiffel:
    def __init__(self, name):
        self.name = name
    def cheer(self):
        print(f"{self.name}, 끝까지 화이팅!")

# %%
a = Aiffel("kim")
b = Aiffel("lee")

# %%
a.cheer()
b.cheer()
# Out:
# kim, 끝까지 화이팅!
# lee, 끝까지 화이팅!

# %%
class Person:
    # 생성자: 객체가 생성될 때 자동으로 호출
    def __init__(self, name, age):
        # self.name, self.age -> 이 인스턴스에 붙는 속성
        self.name = name
        self.age = age
        # person_var = 1
    # 인스턴스 메서드: 첫 번째 인자가 항상 self
    def introduce(self):
        # print(person_var)
        print(f"안녕하세요, 저는 {self.name}이고, {self.age}살 입니다.")

# 인스턴스 생성
p1 = Person("철수", 20)
p2 = Person("영희", 25)

# 메서드 호출
p1.introduce() # 안녕하세요, 저는 철수이고, 20살 입니다.
p2.introduce() # 안녕하세요, 저는 영희이고, 25살 입니다.
# Out:
# 안녕하세요, 저는 철수이고, 20살 입니다.
# 안녕하세요, 저는 영희이고, 25살 입니다.

# %%
class MyClass:
    class_variable = "공통 값" # 모든 인스턴스가 공유

    def __init__(self, value):
        self.instance_variable = value #인스턴스마다 다른 값

a = MyClass('A')
b = MyClass('B')

print(a.class_variable)
print(b.class_variable)
print(a.instance_variable)
print(b.instance_variable)
# Out:
# 공통 값
# 공통 값
# A
# B

# %%
class Foo:
    def func1():    # self 없음
        print("func1")

    def func2(self):    # self 있음
        print("func2")

f = Foo()
# f.func1()   # TypeError 발생 (self를 안 받도록 정의했기 때문)
f.func2()     # 정상 작동
# Out:
# func2

# %%
class Today:
    def __init__(self, movie, popcorn, coffee, dinner):
        self.movie = movie
        self.popcorn = popcorn
        self.coffee = coffee
        self.dinner = dinner
    
    def info(self):
        print(f"오늘 {self.popcorn}과 {self.coffee}를 먹으며 {self.movie} 라는 영화를 본 뒤 저녁으로는 {self.dinner}을 먹었다.")

    def choice(self, choice_movie)
        if
# Out:
# 관객 수가 증가하지 않았습니다. 총 관객수는 70만명 입니다.
# 제목 : 만약에 우리
# 장르 : 멜로/로맨스
# 감독 : 김도영
# 출연 배우 : 구교환, 문가영
# 관객수 : 70만명

# %%
class Today:
    def __init__(self, movie, popcorn, drink, dinner):
        self.movie = movie
        self.popcorn = popcorn
        self.drink = drink
        self.dinner = dinner

    def diary(self):
        print(f"----------------------")
        print(f"📝 오늘의 일기: 오늘은 {self.movie}를 보며 {self.popcorn}와 {self.drink}를 먹었고, 저녁으로는 {self.dinner}를 먹었다.")
   

movie = ["범죄도시", "신과함께", "인셉션", "기생충"]
popcorn = ["팝콘", "카라멜팝콘", "반반팝콘"]
drink = ["커피", "콜라", "사이다"]
dinner = ["김치찌개", "파스타", "짬뽕"]


print(f"---- 영화 목록 ----")
print(f"1.{movie[0]} 2.{movie[1]} 3.{movie[2]} 4.{movie[3]}")
movie1 = int(input("오늘 본 영화를 선택하세요: ")) - 1 
my_movie = movie[movie1]


print(f"---- 팝콘 목록 ----")
print(f"1.{popcorn[0]} 2.{popcorn[1]} 3.{popcorn[2]}")
popcorn1 = int(input("오늘 먹은 팝콘를 선택하세요: ")) - 1
my_popcorn = popcorn[popcorn1]

print(f"---- 음료 목록 ----")
print(f"1.{drink[0]} 2.{drink[1]} 3.{drink[2]}")
drink1 = int(input("함께 먹은 음료를 선택하세요: ")) - 1
my_drink = drink[drink1]

print(f"---- 저녁메뉴 목록 ----")
print(f"1.{dinner[0]} 2.{dinner[1]} 3.{dinner[2]}")
dinner1 = int(input("오늘의 저녁 메뉴를 선택하세요: ")) - 1
my_dinner = dinner[dinner1]

my_package = Today(my_movie, my_popcorn, my_drink, my_dinner)


my_package.diary()
# Out:
# ---- 영화 목록 ----
# 1.범죄도시 2.신과함께 3.인셉션 4.기생충
# ---- 팝콘 목록 ----
# 1.팝콘 2.카라멜팝콘 3.반반팝콘
# ---- 음료 목록 ----
# 1.커피 2.콜라 3.사이다
# ---- 저녁메뉴 목록 ----
# 1.김치찌개 2.파스타 3.짬뽕
# ----------------------
# 📝 오늘의 일기: 오늘은 범죄도시를 보며 팝콘와 커피를 먹었고, 저녁으로는 김치찌개를 먹었다.
