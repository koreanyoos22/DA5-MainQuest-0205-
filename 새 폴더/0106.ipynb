# %%
5 <= 4
# Out:
# False

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
a = 11, 22, 33
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (11, 22, 33)

# %%
point = int(input("당신의 점수는 몇점입니까?"))
if point >= 90:
    print("학점은" 'A' "입니다.")
elif point >= 80:
    print('B')
elif point >= 70:
    print('C')
elif point >= 60:
    print('D')
else:
    print('E')

# %%
for i in range(1,11):
    if i % 2:  
        print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
korean_pretzel = 10
while korean_pretzel:
    print('꽈배기 ', korean_pretzel, '개 있습니다.')
    order = int(input('주문 개수 : '))
    korean_pretzel -= order
    print('남은 꽈배기는 ', korean_pretzel, '개 입니다.')
    print('*'*25)
    if korean_pretzel <= 0:
        print('꽈배기 품절입니다.')
        break
# Out:
# 꽈배기  10 개 있습니다.
# 남은 꽈배기는  8 개 입니다.
# *************************
# 꽈배기  8 개 있습니다.
# 남은 꽈배기는  7 개 입니다.
# *************************
# 꽈배기  7 개 있습니다.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       2 while korean_pretzel:
#       3     print('꽈배기 ', korean_pretzel, '개 있습니다.')
# ----> 4     order = int(input('주문 개수 : '))
#       5     korean_pretzel -= order
#       6     print('남은 꽈배기는 ', korean_pretzel, '개 입니다.')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
korean_pretzel = 40
while korean_pretzel:
    print('꽈배기 ', korean_pretzel, '개 있습니다.')
    order = int(input('주문 개수 : '))
    korean_pretzel -= order
    print('남은 꽈배기는 ', korean_pretzel, '개 입니다.')
    print('*'*25)
    if korean_pretzel <= 0:
        print('꽈배기 품절입니다.')
        break
# Out:
# 꽈배기  40 개 있습니다.
# 남은 꽈배기는  38 개 입니다.
# *************************
# 꽈배기  38 개 있습니다.
# 남은 꽈배기는  36 개 입니다.
# *************************
# 꽈배기  36 개 있습니다.
# 남은 꽈배기는  33 개 입니다.
# *************************
# 꽈배기  33 개 있습니다.
# 남은 꽈배기는  32 개 입니다.
# *************************
# 꽈배기  32 개 있습니다.
# 남은 꽈배기는  30 개 입니다.
# *************************
# 꽈배기  30 개 있습니다.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 4
#       2 while korean_pretzel:
#       3     print('꽈배기 ', korean_pretzel, '개 있습니다.')
# ----> 4     order = int(input('주문 개수 : '))
#       5     korean_pretzel -= order
#       6     print('남은 꽈배기는 ', korean_pretzel, '개 입니다.')
#
# ValueError: invalid literal for int() with base 10: ''

# %%
score = int(input('시험 점수를 입력하세요: '))

# 학점을 저장할 변수를 미리 만듭니다.
grade = ""

if score >= 95:
    grade = 'A+'
elif score >= 90:
    grade = 'A'
elif score >= 85:
    grade = 'B+'
else:
    grade = 'C'

print("당신의 학점은" {grade} "입니다.")
# Out:
# 당신의 학점은 {grade} 입니다.

# %%
list_o = ['a', 'i', 'f', 'f', 'e', 'l']
list_o
# Out:
# ['a', 'i', 'f', 'f', 'e', 'l']
